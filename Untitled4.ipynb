# %% [markdown]
# <a href="https://colab.research.google.com/github/limpst/bibooli/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
modelpath = "./bestmodel2.keras"

# %%
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=20)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=500, validation_split=0.25, callbacks=[early_stopping_callback, checkpointer])
